# %%
#Data Analysis
import numpy as np
import os
import json
trainexamples = []
testexamples = []

def loadtest(direc):
    for each in os.listdir(direc):        
        if '.npy' in each:
            fids = each.split('_')[1][:-4]
            examples = np.load(direc+'/'+each)
            with codecs.open(direc+'/'+each[:-4]+'.json', 'r','utf-8') as infile:
                values = json.load(infile)
            assert(len(examples) == len(values))
            yield examples,fids,values
    return

   
def load(direc):
    examples = []
    fids  = []
    values = []
    for each in os.listdir(direc):        
        try:
            if '.npy' in each:
                fids.append(each.split('_')[1][:-4])
                examples.extend(np.load(direc+'/'+each))
                with open(direc+'/'+each[:-4]+'.json', 'r') as infile:
                    values.extend(json.load(infile))
        except:
            continue
    return examples,fids,values

trainexamples, trainfids, trainvalues = load('../../../data/Datefeature/cv1/train')

trainlabels, trainfeatures = [], []
for each in trainexamples:
    trainfeatures.append(each[1:])
    trainlabels.append(each[0])

testexamples, testfids, testvalues = load('../../../data/Datefeature/cv1/test')
testfeatures, testlabels = [], []
for each in testexamples:
    testfeatures.append(each[1:])
    testlabels.append(each[0])
assert(len(trainvalues)==len(trainlabels))
assert(len(testvalues)==len(testlabels))
print len(trainfeatures[0])
print len(trainfeatures)

X = np.array(trainfeatures)
print X.shape
Y = map(lambda x: 1 if x==3 else 0, trainlabels )
Y = np.array(Y)
print 'No of positive examples %d' %Y.nonzero()[0].shape[0]
print 'Total number of examples %d'%Y.shape[0]
# Out:
# 12
# 25461
# (25461, 12)
# No of positive examples 79
# Total number of examples 25461

# %%
from matplotlib.pyplot import plot
rblue = filter(lambda x: Y[x]==0, range(Y.shape[0]))
rred = filter(lambda x: Y[x]==1, range(Y.shape[0]))
from collections import defaultdict
gaus = defaultdict(float)
gaus1 = defaultdict(float)
for each in X[rblue,d['distance_from_title']]:
    gaus[int(each/10)*10]+=1
for each in X[rred,d['distance_from_title']]:
    gaus1[int(each/10)*10]+=1
for e in gaus: gaus[e]/=len(rblue)
for e in gaus1: gaus1[e]/=len(rred)

x,y = zip(*sorted(gaus.items()))
plot(x,y,'b-')
plt.title('Distribution of  Labels')
x,y = zip(*sorted(gaus1.items()))
plot(x,y,'r-')
#plt.title('Distribution of Negative Labels')

plt.show()

# %%
import numpy as np


with open('../../../data/Datefeature/cv1/train/featurenames.json') as infile:
    featurenames = json.load(infile)
assert(len(featurenames) == len(trainfeatures[0]))


################ ML methods ######################################


import random

from time import time
from sklearn.svm import SVC
from sklearn.feature_selection import chi2
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import f1_score
from sklearn.grid_search import RandomizedSearchCV
from operator import itemgetter
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import randint as sp_randint
from sklearn.cross_validation import StratifiedKFold



d = dict(zip(featurenames,range(len(featurenames))))
print '-----------------'*10
print 'FeatureNames'
for each in d.keys():
    print each
print '-----------------'*10
###################################################################################################################

# Utility function to report best scores
def report(grid_scores, n_top=3):
    top_scores = sorted(grid_scores, key=itemgetter(1), reverse=True)[:n_top]
    for i, score in enumerate(top_scores):
        print("Model with rank: {0}".format(i + 1))
        print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
              score.mean_validation_score,
              np.std(score.cv_validation_scores)))
        print("Parameters: {0}".format(score.parameters))
        if i == 0:
            bestparams = (score.parameters,score.mean_validation_score)
        print("")
    return bestparams

def getf1score(estimator, X, Y):
    #return recall_score(estimator.predict(X),Y)
    return f1_score(estimator.predict(X),Y)



clf1 = SVC(C=1.0)
clf2 = LogisticRegression(penalty='l2', random_state=4,C=1.0)
clf3 = RandomForestClassifier(n_estimators=20)
s3fold = StratifiedKFold(y=Y, n_folds=5,
                                         shuffle=True, random_state=2)
bestparams = []

C = [0.001, 0.001, 0.1, 0.7, 0.5, 0.6, 0.9, 1, 2, 5, 7, 10,50, 70, 100,1000]
gamma = [0.00001, 0.0001,0.001, 0.01, 0.1]
class_weights = [{0:1,1:1},{0:1,1:10},{0:1,1:20},{0:1,1:100},{0:1,1:300}]

param_dist = {"C": C, "gamma":gamma, "class_weight":class_weights}

Xnew = np.delete(X,[d['wordlength'],d['bias']],1)
print Xnew.shape,X.shape


print '#################### SVC  ###############################'
np.random.seed(5)
# run randomized search
n_iter_search = 20
random_search = RandomizedSearchCV(clf1, param_distributions=param_dist, scoring=getf1score,
                                   verbose=2, cv=s3fold )
start = time()
random_search.fit(Xnew, Y)
print("RandomizedSearchCV took %.2f seconds for %d candidates"
      " parameter settings." % ((time() - start), n_iter_search))
bestparams.append(report(random_search.grid_scores_))
print 'Continue ??'
raw_input()

param_dist = {"C": C,"class_weight": class_weights}
print '#################### LOGISTIC REGRESSION ###############################'
random_search = RandomizedSearchCV(clf2, param_distributions=param_dist, scoring=getf1score,
                                   verbose=2 ,cv=s3fold)

random_search.fit(Xnew, Y)
start = time()
print("RandomizedSearchCV took %.2f seconds for %d candidates"
      " parameter settings." % ((time() - start), n_iter_search))
bestparams.append(report(random_search.grid_scores_))
print 'Continue ??'
raw_input()



# specify parameters and distributions to sample from
print '#################### RANDOM FOREST ###############################'
param_dist = {"max_depth": [3, None],
              "max_features": sp_randint(1, 11),
              "min_samples_split": sp_randint(1, 11),
              "min_samples_leaf": sp_randint(1, 11),
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]
             }
random_search = RandomizedSearchCV(clf3, param_distributions=param_dist, scoring=getf1score,
                                   verbose=2 )


start = time()
random_search.fit(Xnew, Y)
print("RandomizedSearchCV took %.2f seconds for %d candidates"
      " parameter settings." % ((time() - start), n_iter_search))
bestparams.append(report(random_search.grid_scores_))
print 'BestParams and score'
print bestparams
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FeatureNames
# isday
# ismonth
# distance_from_title
# isyear
# relative_position
# previous_keywords
# bias
# regexp
# number_ratio
# isdate_mon
# wordlength
# isdate_tag
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# (25461, 10) (25461, 12)
# #################### SVC  ###############################
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] C=100, gamma=1e-05, class_weight={0: 1, 1: 10} ..................
# [CV] ......... C=100, gamma=1e-05, class_weight={0: 1, 1: 10} -   1.1s
# [CV] C=100, gamma=1e-05, class_weight={0: 1, 1: 10} ..................
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    1.1s
# [CV] ......... C=100, gamma=1e-05, class_weight={0: 1, 1: 10} -   1.1s
# [CV] C=100, gamma=1e-05, class_weight={0: 1, 1: 10} ..................
# [CV] ......... C=100, gamma=1e-05, class_weight={0: 1, 1: 10} -   1.1s
# [CV] C=100, gamma=1e-05, class_weight={0: 1, 1: 10} ..................
# [CV] ......... C=100, gamma=1e-05, class_weight={0: 1, 1: 10} -   1.1s
# [CV] C=100, gamma=1e-05, class_weight={0: 1, 1: 10} ..................
# [CV] ......... C=100, gamma=1e-05, class_weight={0: 1, 1: 10} -   1.2s
# [CV] C=2, gamma=0.0001, class_weight={0: 1, 1: 10} ...................
# [CV] .......... C=2, gamma=0.0001, class_weight={0: 1, 1: 10} -   1.3s
# [CV] C=2, gamma=0.0001, class_weight={0: 1, 1: 10} ...................
# [CV] .......... C=2, gamma=0.0001, class_weight={0: 1, 1: 10} -   1.2s
# [CV] C=2, gamma=0.0001, class_weight={0: 1, 1: 10} ...................
# [CV] .......... C=2, gamma=0.0001, class_weight={0: 1, 1: 10} -   1.0s
# [CV] C=2, gamma=0.0001, class_weight={0: 1, 1: 10} ...................
# [CV] .......... C=2, gamma=0.0001, class_weight={0: 1, 1: 10} -   1.3s
# [CV] C=2, gamma=0.0001, class_weight={0: 1, 1: 10} ...................
# [CV] .......... C=2, gamma=0.0001, class_weight={0: 1, 1: 10} -   1.3s
# [CV] C=1, gamma=0.1, class_weight={0: 1, 1: 20} ......................
# [CV] ............. C=1, gamma=0.1, class_weight={0: 1, 1: 20} -   2.0s
# [CV] C=1, gamma=0.1, class_weight={0: 1, 1: 20} ......................
# [CV] ............. C=1, gamma=0.1, class_weight={0: 1, 1: 20} -   1.8s
# [CV] C=1, gamma=0.1, class_weight={0: 1, 1: 20} ......................
# [CV] ............. C=1, gamma=0.1, class_weight={0: 1, 1: 20} -   2.0s
# [CV] C=1, gamma=0.1, class_weight={0: 1, 1: 20} ......................
# [CV] ............. C=1, gamma=0.1, class_weight={0: 1, 1: 20} -   2.1s
# [CV] C=1, gamma=0.1, class_weight={0: 1, 1: 20} ......................
# [CV] ............. C=1, gamma=0.1, class_weight={0: 1, 1: 20} -   1.7s
# [CV] C=0.5, gamma=0.01, class_weight={0: 1, 1: 100} ..................
# [CV] ......... C=0.5, gamma=0.01, class_weight={0: 1, 1: 100} -   2.6s
# [CV] C=0.5, gamma=0.01, class_weight={0: 1, 1: 100} ..................
# [CV] ......... C=0.5, gamma=0.01, class_weight={0: 1, 1: 100} -   2.4s
# [CV] C=0.5, gamma=0.01, class_weight={0: 1, 1: 100} ..................
# [CV] ......... C=0.5, gamma=0.01, class_weight={0: 1, 1: 100} -   2.2s
# [CV] C=0.5, gamma=0.01, class_weight={0: 1, 1: 100} ..................
# [CV] ......... C=0.5, gamma=0.01, class_weight={0: 1, 1: 100} -   2.5s
# [CV] C=0.5, gamma=0.01, class_weight={0: 1, 1: 100} ..................
# [CV] ......... C=0.5, gamma=0.01, class_weight={0: 1, 1: 100} -   2.1s
# [CV] C=0.1, gamma=0.01, class_weight={0: 1, 1: 300} ..................
# [CV] ......... C=0.1, gamma=0.01, class_weight={0: 1, 1: 300} -   4.8s
# [CV] C=0.1, gamma=0.01, class_weight={0: 1, 1: 300} ..................
# [CV] ......... C=0.1, gamma=0.01, class_weight={0: 1, 1: 300} -   4.4s
# [CV] C=0.1, gamma=0.01, class_weight={0: 1, 1: 300} ..................
# [CV] ......... C=0.1, gamma=0.01, class_weight={0: 1, 1: 300} -   4.5s
# [CV] C=0.1, gamma=0.01, class_weight={0: 1, 1: 300} ..................
# [CV] ......... C=0.1, gamma=0.01, class_weight={0: 1, 1: 300} -   5.0s
# [CV] C=0.1, gamma=0.01, class_weight={0: 1, 1: 300} ..................
# [CV] ......... C=0.1, gamma=0.01, class_weight={0: 1, 1: 300} -   4.7s
# [CV] C=0.001, gamma=0.01, class_weight={0: 1, 1: 10} .................
# [CV] ........ C=0.001, gamma=0.01, class_weight={0: 1, 1: 10} -   0.9s
# [CV] C=0.001, gamma=0.01, class_weight={0: 1, 1: 10} .................
# [CV] ........ C=0.001, gamma=0.01, class_weight={0: 1, 1: 10} -   1.0s
# [CV] C=0.001, gamma=0.01, class_weight={0: 1, 1: 10} .................
# [CV] ........ C=0.001, gamma=0.01, class_weight={0: 1, 1: 10} -   1.0s
# [CV] C=0.001, gamma=0.01, class_weight={0: 1, 1: 10} .................
# [CV] ........ C=0.001, gamma=0.01, class_weight={0: 1, 1: 10} -   1.0s
# [CV] C=0.001, gamma=0.01, class_weight={0: 1, 1: 10} .................
# [CV] ........ C=0.001, gamma=0.01, class_weight={0: 1, 1: 10} -   0.9s
# [CV] C=5, gamma=0.01, class_weight={0: 1, 1: 1} ......................
# [CV] ............. C=5, gamma=0.01, class_weight={0: 1, 1: 1} -   0.2s
# [CV] C=5, gamma=0.01, class_weight={0: 1, 1: 1} ......................
# [CV] ............. C=5, gamma=0.01, class_weight={0: 1, 1: 1} -   0.2s
# [CV] C=5, gamma=0.01, class_weight={0: 1, 1: 1} ......................
# [CV] ............. C=5, gamma=0.01, class_weight={0: 1, 1: 1} -   0.2s
# [CV] C=5, gamma=0.01, class_weight={0: 1, 1: 1} ......................
# [CV] ............. C=5, gamma=0.01, class_weight={0: 1, 1: 1} -   0.3s
# [CV] C=5, gamma=0.01, class_weight={0: 1, 1: 1} ......................
# [CV] ............. C=5, gamma=0.01, class_weight={0: 1, 1: 1} -   0.2s
# [CV] C=5, gamma=0.0001, class_weight={0: 1, 1: 10} ...................
# [CV] .......... C=5, gamma=0.0001, class_weight={0: 1, 1: 10} -   1.1s
# [CV] C=5, gamma=0.0001, class_weight={0: 1, 1: 10} ...................
# [CV] .......... C=5, gamma=0.0001, class_weight={0: 1, 1: 10} -   1.1s
# [CV] C=5, gamma=0.0001, class_weight={0: 1, 1: 10} ...................
# [CV] .......... C=5, gamma=0.0001, class_weight={0: 1, 1: 10} -   1.0s
# [CV] C=5, gamma=0.0001, class_weight={0: 1, 1: 10} ...................
# [CV] .......... C=5, gamma=0.0001, class_weight={0: 1, 1: 10} -   1.2s
# [CV] C=5, gamma=0.0001, class_weight={0: 1, 1: 10} ...................
# [CV] .......... C=5, gamma=0.0001, class_weight={0: 1, 1: 10} -   1.2s
# [CV] C=0.5, gamma=0.001, class_weight={0: 1, 1: 20} ..................
# [CV] ......... C=0.5, gamma=0.001, class_weight={0: 1, 1: 20} -   1.5s
# [CV] C=0.5, gamma=0.001, class_weight={0: 1, 1: 20} ..................
# [Parallel(n_jobs=1)]: Done  41 jobs       | elapsed:  1.2min
# [CV] ......... C=0.5, gamma=0.001, class_weight={0: 1, 1: 20} -   1.5s
# [CV] C=0.5, gamma=0.001, class_weight={0: 1, 1: 20} ..................
# [CV] ......... C=0.5, gamma=0.001, class_weight={0: 1, 1: 20} -   1.5s
# [CV] C=0.5, gamma=0.001, class_weight={0: 1, 1: 20} ..................
# [CV] ......... C=0.5, gamma=0.001, class_weight={0: 1, 1: 20} -   1.5s
# [CV] C=0.5, gamma=0.001, class_weight={0: 1, 1: 20} ..................
# [CV] ......... C=0.5, gamma=0.001, class_weight={0: 1, 1: 20} -   1.5s
# [CV] C=0.9, gamma=0.01, class_weight={0: 1, 1: 10} ...................
# [CV] .......... C=0.9, gamma=0.01, class_weight={0: 1, 1: 10} -   0.7s
# [CV] C=0.9, gamma=0.01, class_weight={0: 1, 1: 10} ...................
# [CV] .......... C=0.9, gamma=0.01, class_weight={0: 1, 1: 10} -   0.8s
# [CV] C=0.9, gamma=0.01, class_weight={0: 1, 1: 10} ...................
# [CV] .......... C=0.9, gamma=0.01, class_weight={0: 1, 1: 10} -   0.7s
# [CV] C=0.9, gamma=0.01, class_weight={0: 1, 1: 10} ...................
# [CV] .......... C=0.9, gamma=0.01, class_weight={0: 1, 1: 10} -   0.8s
# [CV] C=0.9, gamma=0.01, class_weight={0: 1, 1: 10} ...................
# [CV] .......... C=0.9, gamma=0.01, class_weight={0: 1, 1: 10} -   0.7s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:  1.3min finished
# RandomizedSearchCV took 80.82 seconds for 20 candidates parameter settings.
# Model with rank: 1
# Mean validation score: 0.536 (std: 0.088)
# Parameters: {'C': 100, 'gamma': 1e-05, 'class_weight': {0: 1, 1: 10}}
#
# Model with rank: 2
# Mean validation score: 0.511 (std: 0.115)
# Parameters: {'C': 1, 'gamma': 0.1, 'class_weight': {0: 1, 1: 20}}
#
# Model with rank: 3
# Mean validation score: 0.504 (std: 0.113)
# Parameters: {'C': 0.9, 'gamma': 0.01, 'class_weight': {0: 1, 1: 10}}
#
# Continue ??
# y
# #################### LOGISTIC REGRESSION ###############################
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] C=0.001, class_weight={0: 1, 1: 20} .............................
# [CV] .................... C=0.001, class_weight={0: 1, 1: 20} -   0.1s
# [CV] C=0.001, class_weight={0: 1, 1: 20} .............................
# [CV] .................... C=0.001, class_weight={0: 1, 1: 20} -   0.1s
# [CV] C=0.001, class_weight={0: 1, 1: 20} .............................
# [CV] .................... C=0.001, class_weight={0: 1, 1: 20} -   0.1s
# [CV] C=0.001, class_weight={0: 1, 1: 20} .............................
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.1s
# [CV] .................... C=0.001, class_weight={0: 1, 1: 20} -   0.1s
# [CV] C=0.001, class_weight={0: 1, 1: 20} .............................
# [CV] .................... C=0.001, class_weight={0: 1, 1: 20} -   0.1s
# [CV] C=0.9, class_weight={0: 1, 1: 1} ................................
# [CV] ....................... C=0.9, class_weight={0: 1, 1: 1} -   0.1s
# [CV] C=0.9, class_weight={0: 1, 1: 1} ................................
# [CV] ....................... C=0.9, class_weight={0: 1, 1: 1} -   0.1s
# [CV] C=0.9, class_weight={0: 1, 1: 1} ................................
# [CV] ....................... C=0.9, class_weight={0: 1, 1: 1} -   0.1s
# [CV] C=0.9, class_weight={0: 1, 1: 1} ................................
# [CV] ....................... C=0.9, class_weight={0: 1, 1: 1} -   0.1s
# [CV] C=0.9, class_weight={0: 1, 1: 1} ................................
# [CV] ....................... C=0.9, class_weight={0: 1, 1: 1} -   0.1s
# [CV] C=50, class_weight={0: 1, 1: 20} ................................
# [CV] ....................... C=50, class_weight={0: 1, 1: 20} -   0.1s
# [CV] C=50, class_weight={0: 1, 1: 20} ................................
# [CV] ....................... C=50, class_weight={0: 1, 1: 20} -   0.1s
# [CV] C=50, class_weight={0: 1, 1: 20} ................................
# [CV] ....................... C=50, class_weight={0: 1, 1: 20} -   0.1s
# [CV] C=50, class_weight={0: 1, 1: 20} ................................
# [CV] ....................... C=50, class_weight={0: 1, 1: 20} -   0.1s
# [CV] C=50, class_weight={0: 1, 1: 20} ................................
# [CV] ....................... C=50, class_weight={0: 1, 1: 20} -   0.1s
# [CV] C=0.1, class_weight={0: 1, 1: 10} ...............................
# [CV] ...................... C=0.1, class_weight={0: 1, 1: 10} -   0.1s
# [CV] C=0.1, class_weight={0: 1, 1: 10} ...............................
# [CV] ...................... C=0.1, class_weight={0: 1, 1: 10} -   0.1s
# [CV] C=0.1, class_weight={0: 1, 1: 10} ...............................
# [CV] ...................... C=0.1, class_weight={0: 1, 1: 10} -   0.1s
# [CV] C=0.1, class_weight={0: 1, 1: 10} ...............................
# [CV] ...................... C=0.1, class_weight={0: 1, 1: 10} -   0.1s
# [CV] C=0.1, class_weight={0: 1, 1: 10} ...............................
# [CV] ...................... C=0.1, class_weight={0: 1, 1: 10} -   0.1s
# [CV] C=70, class_weight={0: 1, 1: 20} ................................
# [CV] ....................... C=70, class_weight={0: 1, 1: 20} -   0.1s
# [CV] C=70, class_weight={0: 1, 1: 20} ................................
# [CV] ....................... C=70, class_weight={0: 1, 1: 20} -   0.1s
# [CV] C=70, class_weight={0: 1, 1: 20} ................................
# [CV] ....................... C=70, class_weight={0: 1, 1: 20} -   0.1s
# [CV] C=70, class_weight={0: 1, 1: 20} ................................
# [CV] ....................... C=70, class_weight={0: 1, 1: 20} -   0.1s
# [CV] C=70, class_weight={0: 1, 1: 20} ................................
# [CV] ....................... C=70, class_weight={0: 1, 1: 20} -   0.1s
# [CV] C=70, class_weight={0: 1, 1: 1} .................................
# [CV] ........................ C=70, class_weight={0: 1, 1: 1} -   0.1s
# [CV] C=70, class_weight={0: 1, 1: 1} .................................
# [CV] ........................ C=70, class_weight={0: 1, 1: 1} -   0.1s
# [CV] C=70, class_weight={0: 1, 1: 1} .................................
# [CV] ........................ C=70, class_weight={0: 1, 1: 1} -   0.1s
# [CV] C=70, class_weight={0: 1, 1: 1} .................................
# [CV] ........................ C=70, class_weight={0: 1, 1: 1} -   0.1s
# [CV] C=70, class_weight={0: 1, 1: 1} .................................
# [CV] ........................ C=70, class_weight={0: 1, 1: 1} -   0.1s
# [CV] C=10, class_weight={0: 1, 1: 1} .................................
# [CV] ........................ C=10, class_weight={0: 1, 1: 1} -   0.1s
# [CV] C=10, class_weight={0: 1, 1: 1} .................................
# [CV] ........................ C=10, class_weight={0: 1, 1: 1} -   0.1s
# [CV] C=10, class_weight={0: 1, 1: 1} .................................
# [CV] ........................ C=10, class_weight={0: 1, 1: 1} -   0.1s
# [CV] C=10, class_weight={0: 1, 1: 1} .................................
# [CV] ........................ C=10, class_weight={0: 1, 1: 1} -   0.1s
# [CV] C=10, class_weight={0: 1, 1: 1} .................................
# [CV] ........................ C=10, class_weight={0: 1, 1: 1} -   0.1s
# [CV] C=0.001, class_weight={0: 1, 1: 100} ............................
# [CV] ................... C=0.001, class_weight={0: 1, 1: 100} -   0.1s
# [CV] C=0.001, class_weight={0: 1, 1: 100} ............................
# [CV] ................... C=0.001, class_weight={0: 1, 1: 100} -   0.1s
# [CV] C=0.001, class_weight={0: 1, 1: 100} ............................
# [CV] ................... C=0.001, class_weight={0: 1, 1: 100} -   0.1s
# [CV] C=0.001, class_weight={0: 1, 1: 100} ............................
# [CV] ................... C=0.001, class_weight={0: 1, 1: 100} -   0.1s
# [CV] C=0.001, class_weight={0: 1, 1: 100} ............................
# [CV] ................... C=0.001, class_weight={0: 1, 1: 100} -   0.1s
# [CV] C=1000, class_weight={0: 1, 1: 100} .............................
# [CV] .................... C=1000, class_weight={0: 1, 1: 100} -   0.1s
# [CV] C=1000, class_weight={0: 1, 1: 100} .............................
# [CV] .................... C=1000, class_weight={0: 1, 1: 100} -   0.1s
# [CV] C=1000, class_weight={0: 1, 1: 100} .............................
# [Parallel(n_jobs=1)]: Done  41 jobs       | elapsed:    3.4s
# [CV] .................... C=1000, class_weight={0: 1, 1: 100} -   0.1s
# [CV] C=1000, class_weight={0: 1, 1: 100} .............................
# [CV] .................... C=1000, class_weight={0: 1, 1: 100} -   0.1s
# [CV] C=1000, class_weight={0: 1, 1: 100} .............................
# [CV] .................... C=1000, class_weight={0: 1, 1: 100} -   0.1s
# [CV] C=0.6, class_weight={0: 1, 1: 20} ...............................
# [CV] ...................... C=0.6, class_weight={0: 1, 1: 20} -   0.1s
# [CV] C=0.6, class_weight={0: 1, 1: 20} ...............................
# [CV] ...................... C=0.6, class_weight={0: 1, 1: 20} -   0.1s
# [CV] C=0.6, class_weight={0: 1, 1: 20} ...............................
# [CV] ...................... C=0.6, class_weight={0: 1, 1: 20} -   0.1s
# [CV] C=0.6, class_weight={0: 1, 1: 20} ...............................
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:    4.2s finished
# [CV] ...................... C=0.6, class_weight={0: 1, 1: 20} -   0.1s
# [CV] C=0.6, class_weight={0: 1, 1: 20} ...............................
# [CV] ...................... C=0.6, class_weight={0: 1, 1: 20} -   0.1s
# RandomizedSearchCV took 0.00 seconds for 20 candidates parameter settings.
# Model with rank: 1
# Mean validation score: 0.424 (std: 0.043)
# Parameters: {'C': 0.1, 'class_weight': {0: 1, 1: 10}}
#
# Model with rank: 2
# Mean validation score: 0.342 (std: 0.047)
# Parameters: {'C': 0.6, 'class_weight': {0: 1, 1: 20}}
#
# Model with rank: 3
# Mean validation score: 0.341 (std: 0.049)
# Parameters: {'C': 50, 'class_weight': {0: 1, 1: 20}}
#
# Continue ??
# y
# #################### RANDOM FOREST ###############################
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV] bootstrap=True, min_samples_leaf=9, min_samples_split=2, criterion=gini, max_features=9, max_depth=None
# [CV]  bootstrap=True, min_samples_leaf=9, min_samples_split=2, criterion=gini, max_features=9, max_depth=None -   0.2s
# [CV] bootstrap=True, min_samples_leaf=9, min_samples_split=2, criterion=gini, max_features=9, max_depth=None
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.2s
# [CV]  bootstrap=True, min_samples_leaf=9, min_samples_split=2, criterion=gini, max_features=9, max_depth=None -   0.2s
# [CV] bootstrap=True, min_samples_leaf=9, min_samples_split=2, criterion=gini, max_features=9, max_depth=None
# [CV]  bootstrap=True, min_samples_leaf=9, min_samples_split=2, criterion=gini, max_features=9, max_depth=None -   0.3s
# [CV] bootstrap=True, min_samples_leaf=4, min_samples_split=5, criterion=gini, max_features=6, max_depth=None
# [CV]  bootstrap=True, min_samples_leaf=4, min_samples_split=5, criterion=gini, max_features=6, max_depth=None -   0.2s
# [CV] bootstrap=True, min_samples_leaf=4, min_samples_split=5, criterion=gini, max_features=6, max_depth=None
# [CV]  bootstrap=True, min_samples_leaf=4, min_samples_split=5, criterion=gini, max_features=6, max_depth=None -   0.2s
# [CV] bootstrap=True, min_samples_leaf=4, min_samples_split=5, criterion=gini, max_features=6, max_depth=None
# [CV]  bootstrap=True, min_samples_leaf=4, min_samples_split=5, criterion=gini, max_features=6, max_depth=None -   0.2s
# [CV] bootstrap=False, min_samples_leaf=6, min_samples_split=10, criterion=gini, max_features=10, max_depth=None
# [CV]  bootstrap=False, min_samples_leaf=6, min_samples_split=10, criterion=gini, max_features=10, max_depth=None -   0.5s
# [CV] bootstrap=False, min_samples_leaf=6, min_samples_split=10, criterion=gini, max_features=10, max_depth=None
# [CV]  bootstrap=False, min_samples_leaf=6, min_samples_split=10, criterion=gini, max_features=10, max_depth=None -   0.4s
# [CV] bootstrap=False, min_samples_leaf=6, min_samples_split=10, criterion=gini, max_features=10, max_depth=None
# [CV]  bootstrap=False, min_samples_leaf=6, min_samples_split=10, criterion=gini, max_features=10, max_depth=None -   0.6s
# [CV] bootstrap=True, min_samples_leaf=1, min_samples_split=1, criterion=gini, max_features=5, max_depth=None
# [CV]  bootstrap=True, min_samples_leaf=1, min_samples_split=1, criterion=gini, max_features=5, max_depth=None -   0.1s
# [CV] bootstrap=True, min_samples_leaf=1, min_samples_split=1, criterion=gini, max_features=5, max_depth=None
# [CV]  bootstrap=True, min_samples_leaf=1, min_samples_split=1, criterion=gini, max_features=5, max_depth=None -   0.2s
# [CV] bootstrap=True, min_samples_leaf=1, min_samples_split=1, criterion=gini, max_features=5, max_depth=None
# [CV]  bootstrap=True, min_samples_leaf=1, min_samples_split=1, criterion=gini, max_features=5, max_depth=None -   0.2s
# [CV] bootstrap=False, min_samples_leaf=8, min_samples_split=10, criterion=gini, max_features=7, max_depth=None
# [CV]  bootstrap=False, min_samples_leaf=8, min_samples_split=10, criterion=gini, max_features=7, max_depth=None -   0.3s
# [CV] bootstrap=False, min_samples_leaf=8, min_samples_split=10, criterion=gini, max_features=7, max_depth=None
# [CV]  bootstrap=False, min_samples_leaf=8, min_samples_split=10, criterion=gini, max_features=7, max_depth=None -   0.4s
# [CV] bootstrap=False, min_samples_leaf=8, min_samples_split=10, criterion=gini, max_features=7, max_depth=None
# [CV]  bootstrap=False, min_samples_leaf=8, min_samples_split=10, criterion=gini, max_features=7, max_depth=None -   0.3s
# [CV] bootstrap=True, min_samples_leaf=4, min_samples_split=9, criterion=gini, max_features=9, max_depth=3
# [CV]  bootstrap=True, min_samples_leaf=4, min_samples_split=9, criterion=gini, max_features=9, max_depth=3 -   0.2s
# [CV] bootstrap=True, min_samples_leaf=4, min_samples_split=9, criterion=gini, max_features=9, max_depth=3
# [CV]  bootstrap=True, min_samples_leaf=4, min_samples_split=9, criterion=gini, max_features=9, max_depth=3 -   0.3s
# [CV] bootstrap=True, min_samples_leaf=4, min_samples_split=9, criterion=gini, max_features=9, max_depth=3
# [CV]  bootstrap=True, min_samples_leaf=4, min_samples_split=9, criterion=gini, max_features=9, max_depth=3 -   0.2s
# [CV] bootstrap=True, min_samples_leaf=1, min_samples_split=4, criterion=entropy, max_features=3, max_depth=None
# [CV]  bootstrap=True, min_samples_leaf=1, min_samples_split=4, criterion=entropy, max_features=3, max_depth=None -   0.1s
# [CV] bootstrap=True, min_samples_leaf=1, min_samples_split=4, criterion=entropy, max_features=3, max_depth=None
# [CV]  bootstrap=True, min_samples_leaf=1, min_samples_split=4, criterion=entropy, max_features=3, max_depth=None -   0.2s
# [CV] bootstrap=True, min_samples_leaf=1, min_samples_split=4, criterion=entropy, max_features=3, max_depth=None
# [CV]  bootstrap=True, min_samples_leaf=1, min_samples_split=4, criterion=entropy, max_features=3, max_depth=None -   0.1s
# [CV] bootstrap=True, min_samples_leaf=1, min_samples_split=7, criterion=entropy, max_features=2, max_depth=3
# [CV]  bootstrap=True, min_samples_leaf=1, min_samples_split=7, criterion=entropy, max_features=2, max_depth=3 -   0.1s
# [CV] bootstrap=True, min_samples_leaf=1, min_samples_split=7, criterion=entropy, max_features=2, max_depth=3
# [CV]  bootstrap=True, min_samples_leaf=1, min_samples_split=7, criterion=entropy, max_features=2, max_depth=3 -   0.1s
# [CV] bootstrap=True, min_samples_leaf=1, min_samples_split=7, criterion=entropy, max_features=2, max_depth=3
# [CV]  bootstrap=True, min_samples_leaf=1, min_samples_split=7, criterion=entropy, max_features=2, max_depth=3 -   0.1s
# [CV] bootstrap=True, min_samples_leaf=4, min_samples_split=6, criterion=gini, max_features=2, max_depth=3
# [CV]  bootstrap=True, min_samples_leaf=4, min_samples_split=6, criterion=gini, max_features=2, max_depth=3 -   0.1s
# [CV] bootstrap=True, min_samples_leaf=4, min_samples_split=6, criterion=gini, max_features=2, max_depth=3
# [CV]  bootstrap=True, min_samples_leaf=4, min_samples_split=6, criterion=gini, max_features=2, max_depth=3 -   0.1s
# [CV] bootstrap=True, min_samples_leaf=4, min_samples_split=6, criterion=gini, max_features=2, max_depth=3
# [CV]  bootstrap=True, min_samples_leaf=4, min_samples_split=6, criterion=gini, max_features=2, max_depth=3 -   0.1s
# [CV] bootstrap=True, min_samples_leaf=4, min_samples_split=7, criterion=gini, max_features=10, max_depth=3
# [CV]  bootstrap=True, min_samples_leaf=4, min_samples_split=7, criterion=gini, max_features=10, max_depth=3 -   0.2s
# [CV] bootstrap=True, min_samples_leaf=4, min_samples_split=7, criterion=gini, max_features=10, max_depth=3
# [CV]  bootstrap=True, min_samples_leaf=4, min_samples_split=7, criterion=gini, max_features=10, max_depth=3 -   0.3s
# [CV] bootstrap=True, min_samples_leaf=4, min_samples_split=7, criterion=gini, max_features=10, max_depth=3
# [CV]  bootstrap=True, min_samples_leaf=4, min_samples_split=7, criterion=gini, max_features=10, max_depth=3 -   0.2s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    6.6s finished
# RandomizedSearchCV took 6.91 seconds for 20 candidates parameter settings.
# Model with rank: 1
# Mean validation score: 0.524 (std: 0.031)
# Parameters: {'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 1, 'criterion': 'gini', 'max_features': 5, 'max_depth': None}
#
# Model with rank: 2
# Mean validation score: 0.433 (std: 0.072)
# Parameters: {'bootstrap': False, 'min_samples_leaf': 6, 'min_samples_split': 10, 'criterion': 'gini', 'max_features': 10, 'max_depth': None}
#
# Model with rank: 3
# Mean validation score: 0.426 (std: 0.004)
# Parameters: {'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 4, 'criterion': 'entropy', 'max_features': 3, 'max_depth': None}
#
# BestParams and score
# [({'C': 100, 'gamma': 1e-05, 'class_weight': {0: 1, 1: 10}}, 0.53622818594838551), ({'C': 0.1, 'class_weight': {0: 1, 1: 10}}, 0.42443456898044735), ({'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 1, 'criterion': 'gini', 'max_features': 5, 'max_depth': None}, 0.52374996243424132)]

# %%
clf = RandomForestClassifier(n_estimators=20, bootstrap=True, min_samples_leaf=1, 
                             min_samples_split=1, criterion='gini', max_features=5, max_depth=None)

random.seed(24)    
rpos = filter(lambda x: Y[x]>0, range(Y.shape[0]))
rneg = filter(lambda x: Y[x]==0, range(Y.shape[0]))

random.shuffle(rpos)
random.shuffle(rneg)

rtrain = rpos[:int(len(rpos)/2)]+rneg[:int(len(rneg)/3)]
rtest = rpos[int(len(rpos)/2):]+rneg[int(len(rneg)/3):]
random.shuffle(rtrain)
random.shuffle(rtest)
print 'Random Forest Needs more negative samples to distinguish'

clf.fit(X[rtrain,:],Y[rtrain])
print f1_score(clf.predict(X[rtest,:]),Y[rtest])
print recall_score(clf.predict(X[rtest,:]),Y[rtest])
print len(clf.predict(X[rtest,:]).nonzero()[0]),len(Y[rtest].nonzero()[0])
print
# Out:
# Random Forest Needs more negative samples to distinguish
# 0.484848484848
# 0.615384615385
# 26 40
